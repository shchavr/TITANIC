# %%
from IPython.display import SVG
from graphviz import Source
from IPython.display import display

from IPython.display import HTML
style = "<style>svg{width:0.1% !important;height:0.1% !important;</style>"
HTML( style )

import os
os.environ["PATH"] += os.pathsep + "C:\\Program Files (x86)\\graphviz2.38\\bin" + os.pathsep + "C:\\Program Files (x86)\\graphviz2.38"

# %%
from sklearn import tree
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from graphviz  import Source
from IPython.display import SVG, display, HTML
style = "<style>svg{width: 100% !important; height: 100% !important;} </style>"

# %%
titanic_data = pd.read_csv("C:\\учеба\\Программирование\\DtaScience Stepik\\ТИТАНИК\\Titanic.csv")

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Отберем очевидные переменные.
# В X положили нужные коллонки
#
# В Y то, что будем предсказывать

# %%
X = titanic_data.drop(['PassengerId', 'Survived', 'Name', 'Ticket', 'Cabin'], axis = 1)
y = titanic_data.Survived

# %% [markdown]
# Изменение переменных, которые записаны в строках

# %%
X = pd.get_dummies(X)
X['Sex_female'] = X['Sex_female'].astype(int)
X['Sex_male'] = X['Sex_male'].astype(int)
X['Embarked_C'] = X['Embarked_C'].astype(int)
X['Embarked_Q'] = X['Embarked_Q'].astype(int)
X['Embarked_S'] = X['Embarked_S'].astype(int)

# %%
X = X.fillna({'Age' : X.Age.median()})

# %%
X.isnull().sum()
# Out:
# Pclass        0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Sex_female    0
# Sex_male      0
# Embarked_C    0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64

# %%
X.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 0       3  22.0      1      0   7.2500           0         1           0
# 1       1  38.0      1      0  71.2833           1         0           1
# 2       3  26.0      0      0   7.9250           1         0           0
# 3       1  35.0      1      0  53.1000           1         0           0
# 4       3  35.0      0      0   8.0500           0         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
clf = tree.DecisionTreeClassifier(criterion = 'entropy')

# %%
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
clf.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# Оверфиттинг

# %%
plt.figure(figsize=(100, 25))
tree.plot_tree(clf, fontsize=10, feature_names=list(X), filled=True)
# Out:
# [Text(0.6212286931818182, 0.975, 'Sex_female <= 0.5\nentropy = 0.961\nsamples = 891\nvalue = [549, 342]'),
#  Text(0.3958664772727273, 0.925, 'Fare <= 26.269\nentropy = 0.699\nsamples = 577\nvalue = [468, 109]'),
#  Text(0.5085475852272727, 0.95, 'True  '),
#  Text(0.19946022727272728, 0.875, 'Age <= 13.5\nentropy = 0.558\nsamples = 415\nvalue = [361, 54]'),
#  Text(0.08181818181818182, 0.825, 'SibSp <= 2.0\nentropy = 0.567\nsamples = 15\nvalue = [2, 13]'),
#  Text(0.07454545454545454, 0.775, 'Parch <= 0.5\nentropy = 0.371\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.06727272727272728, 0.725, 'SibSp <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06, 0.675, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07454545454545454, 0.675, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08181818181818182, 0.725, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.0890909090909091, 0.775, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3171022727272727, 0.825, 'Embarked_C <= 0.5\nentropy = 0.477\nsamples = 400\nvalue = [359, 41]'),
#  Text(0.22693181818181818, 0.775, 'Fare <= 13.25\nentropy = 0.437\nsamples = 355\nvalue = [323, 32]'),
#  Text(0.14659090909090908, 0.725, 'Fare <= 7.91\nentropy = 0.479\nsamples = 291\nvalue = [261, 30]'),
#  Text(0.0890909090909091, 0.675, 'Fare <= 7.865\nentropy = 0.353\nsamples = 150\nvalue = [140, 10]'),
#  Text(0.08181818181818182, 0.625, 'Age <= 32.5\nentropy = 0.424\nsamples = 116\nvalue = [106, 10]'),
#  Text(0.07454545454545454, 0.575, 'Age <= 20.75\nentropy = 0.507\nsamples = 89\nvalue = [79, 10]'),
#  Text(0.06727272727272728, 0.525, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.08181818181818182, 0.525, 'Fare <= 7.763\nentropy = 0.576\nsamples = 73\nvalue = [63, 10]'),
#  Text(0.03272727272727273, 0.475, 'Age <= 27.5\nentropy = 0.451\nsamples = 53\nvalue = [48, 5]'),
#  Text(0.014545454545454545, 0.425, 'Fare <= 7.013\nentropy = 0.672\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.007272727272727273, 0.375, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.02181818181818182, 0.375, 'Fare <= 7.196\nentropy = 0.353\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.014545454545454545, 0.325, 'Fare <= 7.133\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.007272727272727273, 0.275, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.02181818181818182, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.02909090909090909, 0.325, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.05090909090909091, 0.425, 'Fare <= 7.744\nentropy = 0.31\nsamples = 36\nvalue = [34, 2]'),
#  Text(0.04363636363636364, 0.375, 'entropy = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.05818181818181818, 0.375, 'Age <= 28.5\nentropy = 0.592\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.04363636363636364, 0.325, 'SibSp <= 0.5\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.03636363636363636, 0.275, 'entropy = 0.469\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.05090909090909091, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07272727272727272, 0.325, 'Age <= 30.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.06545454545454546, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08, 0.275, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13090909090909092, 0.475, 'Age <= 31.5\nentropy = 0.811\nsamples = 20\nvalue = [15, 5]'),
#  Text(0.12363636363636364, 0.425, 'Fare <= 7.798\nentropy = 0.742\nsamples = 19\nvalue = [15, 4]'),
#  Text(0.11636363636363636, 0.375, 'Age <= 28.5\nentropy = 0.89\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.10909090909090909, 0.325, 'Age <= 26.5\nentropy = 0.946\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.09454545454545454, 0.275, 'Age <= 25.5\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.08727272727272728, 0.225, 'SibSp <= 0.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.08, 0.175, 'Age <= 21.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.07272727272727272, 0.125, 'Fare <= 7.785\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06545454545454546, 0.075, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08, 0.075, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08727272727272728, 0.125, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09454545454545454, 0.175, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10181818181818182, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12363636363636364, 0.275, 'Age <= 27.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.11636363636363636, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13090909090909092, 0.225, 'Fare <= 7.785\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.12363636363636364, 0.175, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13818181818181818, 0.175, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12363636363636364, 0.325, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13090909090909092, 0.375, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.13818181818181818, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0890909090909091, 0.575, 'entropy = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(0.09636363636363636, 0.625, 'entropy = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(0.2040909090909091, 0.675, 'Fare <= 7.988\nentropy = 0.589\nsamples = 141\nvalue = [121, 20]'),
#  Text(0.16727272727272727, 0.625, 'SibSp <= 1.5\nentropy = 0.961\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.16, 0.575, 'SibSp <= 0.5\nentropy = 0.994\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.15272727272727274, 0.525, 'Age <= 26.0\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.14545454545454545, 0.475, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.16, 0.475, 'Age <= 31.5\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.15272727272727274, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16727272727272727, 0.425, 'Age <= 41.5\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.16, 0.375, 'Age <= 35.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.15272727272727274, 0.325, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.16727272727272727, 0.325, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.17454545454545456, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16727272727272727, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17454545454545456, 0.575, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2409090909090909, 0.625, 'Age <= 19.5\nentropy = 0.521\nsamples = 128\nvalue = [113, 15]'),
#  Text(0.19636363636363635, 0.575, 'Fare <= 8.104\nentropy = 0.722\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.18181818181818182, 0.525, 'Age <= 17.0\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.17454545454545456, 0.475, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1890909090909091, 0.475, 'Age <= 18.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.18181818181818182, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19636363636363635, 0.425, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2109090909090909, 0.525, 'Age <= 18.5\nentropy = 0.353\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.20363636363636364, 0.475, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.21818181818181817, 0.475, 'Fare <= 10.335\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.2109090909090909, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.22545454545454546, 0.425, 'Fare <= 11.75\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.21818181818181817, 0.375, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.23272727272727273, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.28545454545454546, 0.575, 'Age <= 26.5\nentropy = 0.475\nsamples = 108\nvalue = [97, 11]'),
#  Text(0.2781818181818182, 0.525, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.2927272727272727, 0.525, 'Fare <= 8.081\nentropy = 0.592\nsamples = 77\nvalue = [66, 11]'),
#  Text(0.24727272727272728, 0.475, 'Age <= 31.25\nentropy = 0.371\nsamples = 28\nvalue = [26, 2]'),
#  Text(0.24, 0.425, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.2545454545454545, 0.425, 'Age <= 33.0\nentropy = 0.65\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.24727272727272728, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26181818181818184, 0.375, 'Age <= 44.5\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.2545454545454545, 0.325, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.2690909090909091, 0.325, 'Age <= 47.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.26181818181818184, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.27636363636363637, 0.275, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3381818181818182, 0.475, 'Fare <= 8.238\nentropy = 0.688\nsamples = 49\nvalue = [40, 9]'),
#  Text(0.33090909090909093, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34545454545454546, 0.425, 'Fare <= 8.658\nentropy = 0.65\nsamples = 48\nvalue = [40, 8]'),
#  Text(0.3381818181818182, 0.375, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3527272727272727, 0.375, 'Age <= 31.5\nentropy = 0.684\nsamples = 44\nvalue = [36, 8]'),
#  Text(0.31272727272727274, 0.325, 'Fare <= 10.0\nentropy = 0.811\nsamples = 20\nvalue = [15, 5]'),
#  Text(0.2909090909090909, 0.275, 'Age <= 27.5\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.28363636363636363, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.29818181818181816, 0.225, 'Age <= 28.5\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.2909090909090909, 0.175, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3054545454545455, 0.175, 'Fare <= 9.492\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.29818181818181816, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.31272727272727274, 0.125, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.33454545454545453, 0.275, 'Fare <= 11.75\nentropy = 0.65\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.32727272727272727, 0.225, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3418181818181818, 0.225, 'Age <= 30.5\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.33454545454545453, 0.175, 'Age <= 29.0\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.32727272727272727, 0.125, 'Age <= 27.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.32, 0.075, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.33454545454545453, 0.075, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3418181818181818, 0.125, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3490909090909091, 0.175, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3927272727272727, 0.325, 'Pclass <= 2.5\nentropy = 0.544\nsamples = 24\nvalue = [21, 3]'),
#  Text(0.38545454545454544, 0.275, 'Age <= 59.5\nentropy = 0.61\nsamples = 20\nvalue = [17, 3]'),
#  Text(0.3709090909090909, 0.225, 'Fare <= 12.762\nentropy = 0.523\nsamples = 17\nvalue = [15, 2]'),
#  Text(0.36363636363636365, 0.175, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.3781818181818182, 0.175, 'Age <= 45.0\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.3709090909090909, 0.125, 'Age <= 40.5\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.36363636363636365, 0.075, 'Age <= 35.0\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.3563636363636364, 0.025, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3709090909090909, 0.025, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3781818181818182, 0.075, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.38545454545454544, 0.125, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4, 0.225, 'Age <= 64.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3927272727272727, 0.175, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4072727272727273, 0.175, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4, 0.275, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.30727272727272725, 0.725, 'Fare <= 22.887\nentropy = 0.201\nsamples = 64\nvalue = [62, 2]'),
#  Text(0.3, 0.675, 'entropy = 0.0\nsamples = 37\nvalue = [37, 0]'),
#  Text(0.3145454545454546, 0.675, 'Fare <= 23.35\nentropy = 0.381\nsamples = 27\nvalue = [25, 2]'),
#  Text(0.30727272727272725, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32181818181818184, 0.625, 'Age <= 33.0\nentropy = 0.235\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.3145454545454546, 0.575, 'Age <= 31.5\nentropy = 0.414\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.30727272727272725, 0.525, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.32181818181818184, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3290909090909091, 0.575, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.4072727272727273, 0.775, 'Fare <= 15.148\nentropy = 0.722\nsamples = 45\nvalue = [36, 9]'),
#  Text(0.3927272727272727, 0.725, 'Age <= 29.5\nentropy = 0.552\nsamples = 39\nvalue = [34, 5]'),
#  Text(0.38545454545454544, 0.675, 'Age <= 28.75\nentropy = 0.65\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.3781818181818182, 0.625, 'Age <= 22.5\nentropy = 0.579\nsamples = 29\nvalue = [25, 4]'),
#  Text(0.3527272727272727, 0.575, 'Age <= 18.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.34545454545454546, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.36, 0.525, 'Fare <= 5.619\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.3527272727272727, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36727272727272725, 0.475, 'Age <= 21.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.36, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.37454545454545457, 0.425, 'Fare <= 7.227\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.36727272727272725, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38181818181818183, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4036363636363636, 0.575, 'Pclass <= 2.5\nentropy = 0.426\nsamples = 23\nvalue = [21, 2]'),
#  Text(0.3890909090909091, 0.525, 'Fare <= 14.454\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.38181818181818183, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.39636363636363636, 0.475, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.41818181818181815, 0.525, 'Fare <= 7.227\nentropy = 0.286\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.4109090909090909, 0.475, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4254545454545455, 0.475, 'Fare <= 7.562\nentropy = 0.371\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.41818181818181815, 0.425, 'Age <= 25.75\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.4109090909090909, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4254545454545455, 0.375, 'Age <= 28.25\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.41818181818181815, 0.325, 'entropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.43272727272727274, 0.325, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.43272727272727274, 0.425, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.3927272727272727, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4, 0.675, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.4218181818181818, 0.725, 'Fare <= 20.233\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.41454545454545455, 0.675, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4290909090909091, 0.675, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5922727272727273, 0.875, 'SibSp <= 2.5\nentropy = 0.924\nsamples = 162\nvalue = [107.0, 55.0]'),
#  Text(0.5704545454545454, 0.825, 'Age <= 13.5\nentropy = 0.964\nsamples = 139\nvalue = [85.0, 54.0]'),
#  Text(0.5631818181818182, 0.775, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5777272727272728, 0.775, 'Fare <= 26.469\nentropy = 0.939\nsamples = 132\nvalue = [85, 47]'),
#  Text(0.5704545454545454, 0.725, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.585, 0.725, 'Age <= 53.0\nentropy = 0.921\nsamples = 128\nvalue = [85, 43]'),
#  Text(0.49, 0.675, 'Fare <= 26.775\nentropy = 0.956\nsamples = 106\nvalue = [66, 40]'),
#  Text(0.4618181818181818, 0.625, 'Age <= 46.5\nentropy = 0.764\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.45454545454545453, 0.575, 'Embarked_S <= 0.5\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.44727272727272727, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4618181818181818, 0.525, 'Age <= 39.5\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.45454545454545453, 0.475, 'Age <= 31.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.44727272727272727, 0.425, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4618181818181818, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4690909090909091, 0.475, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4690909090909091, 0.575, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5181818181818182, 0.625, 'Fare <= 29.1\nentropy = 0.925\nsamples = 97\nvalue = [64, 33]'),
#  Text(0.5109090909090909, 0.575, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.5254545454545455, 0.575, 'Fare <= 30.598\nentropy = 0.954\nsamples = 88\nvalue = [55, 33]'),
#  Text(0.4909090909090909, 0.525, 'Age <= 28.5\nentropy = 0.881\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.48363636363636364, 0.475, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.49818181818181817, 0.475, 'Fare <= 30.285\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.4909090909090909, 0.425, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5054545454545455, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.56, 0.525, 'Fare <= 52.277\nentropy = 0.918\nsamples = 78\nvalue = [52, 26]'),
#  Text(0.5272727272727272, 0.475, 'Age <= 47.5\nentropy = 0.619\nsamples = 26\nvalue = [22, 4]'),
#  Text(0.52, 0.425, 'Fare <= 36.125\nentropy = 0.529\nsamples = 25\nvalue = [22, 3]'),
#  Text(0.5127272727272727, 0.375, 'Fare <= 35.25\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.49818181818181817, 0.325, 'Age <= 39.5\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.4909090909090909, 0.275, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.5054545454545455, 0.275, 'Age <= 43.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.49818181818181817, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5127272727272727, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5272727272727272, 0.325, 'Age <= 36.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.52, 0.275, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5345454545454545, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5272727272727272, 0.375, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.5345454545454545, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5927272727272728, 0.475, 'Fare <= 59.087\nentropy = 0.983\nsamples = 52\nvalue = [30.0, 22.0]'),
#  Text(0.5563636363636364, 0.425, 'Age <= 22.0\nentropy = 0.896\nsamples = 16\nvalue = [5, 11]'),
#  Text(0.5490909090909091, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5636363636363636, 0.375, 'Age <= 49.5\nentropy = 0.837\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.5563636363636364, 0.325, 'Age <= 27.5\nentropy = 0.75\nsamples = 14\nvalue = [3, 11]'),
#  Text(0.5490909090909091, 0.275, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5636363636363636, 0.275, 'Age <= 29.5\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.5563636363636364, 0.225, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.5709090909090909, 0.225, 'Fare <= 54.798\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.5636363636363636, 0.175, 'Fare <= 52.827\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5563636363636364, 0.125, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5709090909090909, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5781818181818181, 0.175, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5709090909090909, 0.325, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6290909090909091, 0.425, 'Fare <= 379.925\nentropy = 0.888\nsamples = 36\nvalue = [25, 11]'),
#  Text(0.6218181818181818, 0.375, 'Fare <= 134.642\nentropy = 0.834\nsamples = 34\nvalue = [25, 9]'),
#  Text(0.6145454545454545, 0.325, 'Fare <= 86.29\nentropy = 0.906\nsamples = 28\nvalue = [19, 9]'),
#  Text(0.5927272727272728, 0.275, 'Embarked_C <= 0.5\nentropy = 0.65\nsamples = 18\nvalue = [15, 3]'),
#  Text(0.5854545454545454, 0.225, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.6, 0.225, 'Fare <= 77.965\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.5927272727272728, 0.175, 'Fare <= 62.369\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5854545454545454, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6, 0.125, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6072727272727273, 0.175, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6363636363636364, 0.275, 'Embarked_S <= 0.5\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.6290909090909091, 0.225, 'Age <= 17.5\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.6218181818181818, 0.175, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6363636363636364, 0.175, 'Fare <= 98.752\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.6290909090909091, 0.125, 'Embarked_Q <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6218181818181818, 0.075, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6363636363636364, 0.075, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6436363636363637, 0.125, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6436363636363637, 0.225, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6290909090909091, 0.325, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.6363636363636364, 0.375, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.68, 0.675, 'Age <= 75.5\nentropy = 0.575\nsamples = 22\nvalue = [19, 3]'),
#  Text(0.6727272727272727, 0.625, 'Embarked_S <= 0.5\nentropy = 0.454\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.6654545454545454, 0.575, 'SibSp <= 0.5\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.6581818181818182, 0.525, 'Age <= 57.0\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.6509090909090909, 0.475, 'Fare <= 33.098\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6436363636363637, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6581818181818182, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6654545454545454, 0.475, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6727272727272727, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.68, 0.575, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.6872727272727273, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6140909090909091, 0.825, 'Age <= 3.5\nentropy = 0.258\nsamples = 23\nvalue = [22, 1]'),
#  Text(0.6068181818181818, 0.775, 'Age <= 2.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.5995454545454545, 0.725, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6140909090909091, 0.725, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6213636363636363, 0.775, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.8465909090909091, 0.925, 'Pclass <= 2.5\nentropy = 0.824\nsamples = 314\nvalue = [81.0, 233.0]'),
#  Text(0.7339098011363636, 0.95, '  False'),
#  Text(0.7490909090909091, 0.875, 'Fare <= 28.856\nentropy = 0.299\nsamples = 170\nvalue = [9, 161]'),
#  Text(0.7345454545454545, 0.825, 'Fare <= 28.231\nentropy = 0.469\nsamples = 70\nvalue = [7, 63]'),
#  Text(0.7272727272727273, 0.775, 'Age <= 23.5\nentropy = 0.426\nsamples = 69\nvalue = [6.0, 63.0]'),
#  Text(0.72, 0.725, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.7345454545454545, 0.725, 'Age <= 27.5\nentropy = 0.503\nsamples = 54\nvalue = [6, 48]'),
#  Text(0.7163636363636363, 0.675, 'Age <= 25.5\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.7018181818181818, 0.625, 'Fare <= 13.75\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.6945454545454546, 0.575, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7090909090909091, 0.575, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.730909090909091, 0.625, 'Fare <= 17.429\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.7236363636363636, 0.575, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7381818181818182, 0.575, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7527272727272727, 0.675, 'Age <= 37.0\nentropy = 0.365\nsamples = 43\nvalue = [3, 40]'),
#  Text(0.7454545454545455, 0.625, 'entropy = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.76, 0.625, 'Age <= 39.0\nentropy = 0.629\nsamples = 19\nvalue = [3, 16]'),
#  Text(0.7527272727272727, 0.575, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7672727272727272, 0.575, 'Age <= 56.0\nentropy = 0.503\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.7527272727272727, 0.525, 'SibSp <= 0.5\nentropy = 0.337\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.7454545454545455, 0.475, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.76, 0.475, 'Parch <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.7527272727272727, 0.425, 'Age <= 43.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7454545454545455, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.76, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7672727272727272, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7818181818181819, 0.525, 'Fare <= 18.525\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7745454545454545, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7890909090909091, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7418181818181818, 0.775, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7636363636363637, 0.825, 'Age <= 2.5\nentropy = 0.141\nsamples = 100\nvalue = [2, 98]'),
#  Text(0.7563636363636363, 0.775, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7709090909090909, 0.775, 'Parch <= 1.5\nentropy = 0.081\nsamples = 99\nvalue = [1, 98]'),
#  Text(0.7636363636363637, 0.725, 'entropy = 0.0\nsamples = 84\nvalue = [0, 84]'),
#  Text(0.7781818181818182, 0.725, 'Age <= 24.5\nentropy = 0.353\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.7709090909090909, 0.675, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.7854545454545454, 0.675, 'Age <= 28.0\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.7781818181818182, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7927272727272727, 0.625, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9440909090909091, 0.875, 'Fare <= 23.35\nentropy = 1.0\nsamples = 144\nvalue = [72, 72]'),
#  Text(0.9172727272727272, 0.825, 'Age <= 36.5\nentropy = 0.977\nsamples = 117\nvalue = [48, 69]'),
#  Text(0.8854545454545455, 0.775, 'Embarked_S <= 0.5\nentropy = 0.959\nsamples = 110\nvalue = [42, 68]'),
#  Text(0.8436363636363636, 0.725, 'Fare <= 15.621\nentropy = 0.86\nsamples = 53\nvalue = [15, 38]'),
#  Text(0.8363636363636363, 0.675, 'Fare <= 13.935\nentropy = 0.918\nsamples = 45\nvalue = [15, 30]'),
#  Text(0.8109090909090909, 0.625, 'Age <= 17.0\nentropy = 0.758\nsamples = 32\nvalue = [7, 25]'),
#  Text(0.8036363636363636, 0.575, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.8181818181818182, 0.575, 'Parch <= 1.0\nentropy = 0.855\nsamples = 25\nvalue = [7.0, 18.0]'),
#  Text(0.8109090909090909, 0.525, 'Age <= 18.5\nentropy = 0.811\nsamples = 24\nvalue = [6, 18]'),
#  Text(0.8036363636363636, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8181818181818182, 0.475, 'Fare <= 8.008\nentropy = 0.755\nsamples = 23\nvalue = [5, 18]'),
#  Text(0.8109090909090909, 0.425, 'Age <= 29.25\nentropy = 0.684\nsamples = 22\nvalue = [4, 18]'),
#  Text(0.8036363636363636, 0.375, 'Fare <= 7.769\nentropy = 0.592\nsamples = 21\nvalue = [3, 18]'),
#  Text(0.7963636363636364, 0.325, 'Age <= 21.5\nentropy = 0.722\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.7890909090909091, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8036363636363636, 0.275, 'Fare <= 7.681\nentropy = 0.592\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.7890909090909091, 0.225, 'Embarked_C <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7818181818181819, 0.175, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7963636363636364, 0.175, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8181818181818182, 0.225, 'Fare <= 7.744\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.8109090909090909, 0.175, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8254545454545454, 0.175, 'Age <= 25.0\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.8181818181818182, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8327272727272728, 0.125, 'entropy = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.8109090909090909, 0.325, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8181818181818182, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8254545454545454, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8254545454545454, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8618181818181818, 0.625, 'Embarked_C <= 0.5\nentropy = 0.961\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.8472727272727273, 0.575, 'Age <= 30.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.84, 0.525, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8545454545454545, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8763636363636363, 0.575, 'Age <= 28.5\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.8690909090909091, 0.525, 'Age <= 16.0\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.8618181818181818, 0.475, 'Age <= 14.75\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8545454545454545, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8690909090909091, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8763636363636363, 0.475, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8836363636363637, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.850909090909091, 0.675, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.9272727272727272, 0.725, 'Age <= 32.0\nentropy = 0.998\nsamples = 57\nvalue = [27, 30]'),
#  Text(0.92, 0.675, 'Fare <= 7.763\nentropy = 1.0\nsamples = 54\nvalue = [27, 27]'),
#  Text(0.8981818181818182, 0.625, 'Age <= 25.5\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.8909090909090909, 0.575, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.9054545454545454, 0.575, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9418181818181818, 0.625, 'Fare <= 10.825\nentropy = 0.995\nsamples = 48\nvalue = [26, 22]'),
#  Text(0.92, 0.575, 'Fare <= 10.152\nentropy = 0.918\nsamples = 27\nvalue = [18, 9]'),
#  Text(0.9127272727272727, 0.525, 'Parch <= 0.5\nentropy = 0.954\nsamples = 24\nvalue = [15, 9]'),
#  Text(0.9054545454545454, 0.475, 'Fare <= 9.84\nentropy = 0.902\nsamples = 22\nvalue = [15.0, 7.0]'),
#  Text(0.8981818181818182, 0.425, 'Fare <= 8.767\nentropy = 0.863\nsamples = 21\nvalue = [15, 6]'),
#  Text(0.8909090909090909, 0.375, 'Fare <= 8.673\nentropy = 0.937\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.8836363636363637, 0.325, 'Age <= 27.5\nentropy = 0.896\nsamples = 16\nvalue = [11, 5]'),
#  Text(0.8763636363636363, 0.275, 'Age <= 25.5\nentropy = 0.994\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.8690909090909091, 0.225, 'Age <= 22.5\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.8618181818181818, 0.175, 'Age <= 18.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.8545454545454545, 0.125, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8690909090909091, 0.125, 'Fare <= 8.258\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8618181818181818, 0.075, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8763636363636363, 0.075, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8763636363636363, 0.175, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8836363636363637, 0.225, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8909090909090909, 0.275, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8981818181818182, 0.325, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9054545454545454, 0.375, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9127272727272727, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.92, 0.475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9272727272727272, 0.525, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9636363636363636, 0.575, 'Fare <= 17.25\nentropy = 0.959\nsamples = 21\nvalue = [8, 13]'),
#  Text(0.9418181818181818, 0.525, 'Age <= 25.0\nentropy = 0.619\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.9345454545454546, 0.475, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9490909090909091, 0.475, 'Age <= 26.5\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.9418181818181818, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9563636363636364, 0.425, 'SibSp <= 0.5\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.9490909090909091, 0.375, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9636363636363636, 0.375, 'Fare <= 15.25\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9563636363636364, 0.325, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9709090909090909, 0.325, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9854545454545455, 0.525, 'Fare <= 21.55\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.9781818181818182, 0.475, 'Age <= 30.0\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.9709090909090909, 0.425, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9854545454545455, 0.425, 'Fare <= 19.262\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9781818181818182, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9927272727272727, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9927272727272727, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9345454545454546, 0.675, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9490909090909091, 0.775, 'Age <= 55.0\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.9418181818181818, 0.725, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.9563636363636364, 0.725, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9709090909090909, 0.825, 'Parch <= 0.5\nentropy = 0.503\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.9636363636363636, 0.775, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9781818181818182, 0.775, 'Fare <= 31.331\nentropy = 0.391\nsamples = 26\nvalue = [24, 2]'),
#  Text(0.9709090909090909, 0.725, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.9854545454545455, 0.725, 'Fare <= 32.881\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.9781818181818182, 0.675, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9927272727272727, 0.675, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]')]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size = 0.33, random_state = 42)

# %%
X_train.shape
# Out:
# (596, 10)

# %%
X_test.shape
# Out:
# (295, 10)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %% [markdown]
# Сравниваем насколько хорошо наше дерево предсказывает ответы на train и test

# %% [markdown]
# Предсказываем число правильных ответов

# %%
clf.score(X, y)
# Out:
# 0.9797979797979798

# %%
clf = tree.DecisionTreeClassifier (criterion = 'entropy', max_depth = 3)

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
clf.score(X_train, y_train)
# Out:
# 0.8238255033557047

# %% [markdown]
# Обучаем 99 деревьев. для кажого из них предсказал события и сохранил точность классификации

# %%
scores_data = pd.DataFrame()

# %%
max_depth_values = range (1,100)
for max_depth in max_depth_values:
    clf = tree.DecisionTreeClassifier (criterion = 'entropy', max_depth=max_depth)
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train, y_train)
    test_score = clf.score(X_test, y_test)
    
    mean_cross_val_score = cross_val_score(clf, X_train, y_train, cv=5).mean()
    
    temp_score_data = pd.DataFrame({'max_depth': [max_depth], 
                                    'train_score': [train_score], 
                                    'test_score': [test_score],
                                    'cross_val_score' : [mean_cross_val_score]})
    
    scores_data = pd.concat([scores_data, temp_score_data])

# %%
scores_data.head()
# Out:
#    max_depth  train_score  test_score  cross_val_score
# 0          1     0.781879    0.796610         0.781961
# 0          2     0.805369    0.776271         0.770196
# 0          3     0.823826    0.820339         0.790322
# 0          4     0.833893    0.823729         0.788627
# 0          5     0.840604    0.810169         0.797031

# %%
scores_data_long.query("set_type == 'cross_val_score' ").head(20)
# Out:
#      max_depth         set_type     score
# 198          1  cross_val_score  0.781961
# 199          2  cross_val_score  0.770196
# 200          3  cross_val_score  0.790322
# 201          4  cross_val_score  0.788627
# 202          5  cross_val_score  0.797031
# 203          6  cross_val_score  0.803754
# 204          7  cross_val_score  0.802059
# 205          8  cross_val_score  0.805406
# 206          9  cross_val_score  0.803725
# 207         10  cross_val_score  0.802031
# 208         11  cross_val_score  0.805392
# 209         12  cross_val_score  0.790294
# 210         13  cross_val_score  0.808754
# 211         14  cross_val_score  0.788599
# 212         15  cross_val_score  0.783585
# 213         16  cross_val_score  0.781933
# 214         17  cross_val_score  0.780224
# 215         18  cross_val_score  0.781947
# 216         19  cross_val_score  0.770154
# 217         20  cross_val_score  0.770182

# %%
scores_data_long = pd.melt(scores_data, id_vars = ['max_depth'], 
                           value_vars = ['train_score','test_score', 'cross_val_score'], 
                           var_name = 'set_type', 
                           value_name = 'score',)

sns.lineplot(x='max_depth', y='score', hue='set_type', data=scores_data_long)
# Out:
# <Axes: xlabel='max_depth', ylabel='score'>

# %% [markdown]
# анализ графика:
# train score:
# - растет с увеличением глубины дерева
# - что не всегда ведет к нахождению общих закономерностей в исследуемых данных
#
# test score:
# - изначально невелик (модель еще не доучилась)
# - на промежутке 3-5 score максимален (оптимальное состояние: закономерность с изученных данных переносится на новые)
# - с дальнейшим увеличением глубины test score начинает падать (переход от недообученности к переобученности)

# %%
from sklearn.model_selection import GridSearchCV

parametrs={'criterion':['gini', 'entropy'], 'max_depth': range(1, 30)}
clf=tree.DecisionTreeClassifier()
grid_search_cv_clf=GridSearchCV(clf, parametrs, cv=5)
grid_search_cv_clf.fit(X_train, y_train)
grid_search_cv_clf.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 6}

# %%
parameters={'criterion':['gini', 'entropy'], 'max_depth':range(1, 150)}
grid_search_cv_clf=GridSearchCV(clf, parameters, cv=100)

# %%
from sklearn.model_selection import cross_val_score

# %%
clf = tree.DecisionTreeClassifier (criterion = 'entropy', max_depth = 4)

# %%
cross_val_score(clf, X_train, y_train, cv=5).mean()
#это средняя точность на кроссвалидации
# Out:
# 0.7886274509803922

# %%
best_clf = tree.DecisionTreeClassifier(criterion='entropy', max_depth=10)
best_clf.fit(X_train, y_train)
best_clf.score(X_test, y_test)
# Out:
# 0.7966101694915254

# %% [markdown]
# задание 2.4

# %%
tren = pd.read_csv("C:\\учеба\\Программирование\\DtaScience Stepik\\dogs_n_cats.csv")

# %%
tren.head()
# Out:
#    Длина  Высота  Шерстист  Гавкает  Лазает по деревьям      Вид
# 0     15    18.0         1        1                   0  собачка
# 1     20    24.0         1        0                   0  собачка
# 2     34    40.8         1        1                   0  собачка
# 3     26    31.2         1        1                   0  собачка
# 4     16    19.2         1        1                   0  собачка

# %%
df = pd.DataFrame(tren)

# %%
print(df.head())
# Out:
#    Длина  Высота  Шерстист  Гавкает  Лазает по деревьям      Вид
# 0     15    18.0         1        1                   0  собачка
# 1     20    24.0         1        0                   0  собачка
# 2     34    40.8         1        1                   0  собачка
# 3     26    31.2         1        1                   0  собачка
# 4     16    19.2         1        1                   0  собачка

# %%
temp_score_data = pd.DataFrame({'max_depth': [max_depth], 
                                    'train_score': [train_score], 
                                    'test_score': [test_score],
                                    'cross_val_score' : [mean_cross_val_score]})

# %%
dogs_n_cats_train
# Out:
#      Длина  Высота  Шерстист  Гавкает  Лазает по деревьям      Вид
# 0       15    18.0         1        1                   0  собачка
# 1       20    24.0         1        0                   0  собачка
# 2       34    40.8         1        1                   0  собачка
# 3       26    31.2         1        1                   0  собачка
# 4       16    19.2         1        1                   0  собачка
# ..     ...     ...       ...      ...                 ...      ...
# 995      8     3.2         1        0                   1    котик
# 996      7     2.8         1        0                   1    котик
# 997      6     2.4         1        0                   1    котик
# 998      7     2.8         1        0                   1    котик
# 999     11     4.4         1        0                   1    котик
#
# [1000 rows x 6 columns]

# %%
# Загрузка данных
dogs_n_cats_train = pd.read_csv('https://stepik.org/media/attachments/course/4852/dogs_n_cats.csv')
dogs_n_cats_test = pd.read_json("C:\\Users\\shcha\\Downloads\\dataset_209691_15 (9).txt")  # Заменить на ваш файл и путь к нему

# Создание выборок
X_train = dogs_n_cats_train.drop(['Вид'], axis=1)
y_train = dogs_n_cats_train['Вид']

# Объявление модели
clf = DecisionTreeClassifier()
# Обучение модели на тренировочных данных
clf.fit(X_train, y_train)

# Предсказание на тестовых данных с записью результатов в pd.Series с названием колонки 'Вид'
y_pred = pd.Series(clf.predict(dogs_n_cats_test), name='Вид')

# Подсчет значений в предсказанных данных
y_pred.value_counts()
# Out:
# Вид
# собачка    58
# котик      42
# Name: count, dtype: int64
